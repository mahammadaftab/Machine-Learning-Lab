# %% [markdown]
# <a href="https://colab.research.google.com/github/mahammadaftab/Machine-Learning-Lab/blob/main/Experiment_7b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score

# %%
df=sns.load_dataset("mpg")

# %%
df=df.dropna()

# %%
X=df["horsepower"].values.reshape(-1,1)
y=df["mpg"].values

# %%
X=X.astype(float)

# %%
poly=PolynomialFeatures(degree=2)
X_poly=poly.fit_transform(X)

# %%
model=LinearRegression()
model.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_poly)

# %%
r2=r2_score(y,y_pred)
mse=mean_squared_error(y,y_pred)

# %%
print(f"R2 Score: {r2:.4f}")
print(f"mean squared error: {mse:.4f}")
# Out:
# R2 Score: 0.6876
# mean squared error: 18.9848

# %%
X_range=np.linspace(X.min(),X.max(),100).reshape(-1,1)
X_range_poly=poly.transform(X_range)
X_range_pred=model.predict(X_range_poly)

# %%
plt.scatter(X,y,color='blue',label="Actual data")
plt.plot(X_range,X_range_pred,color='red',label="polynomial regression (Degree=2)")
plt.xlabel("horsepower")
plt.ylabel("mpg")
plt.title("Polynomial Regression on Auto MPG Dataset")
plt.legend()
plt.show()
